# %%
import pandas as pd
import tensorflow as tf
import codecs
import numpy as np
import math
import csv
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import recall_score, precision_score # New
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn import preprocessing
import keras
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from keras.layers import merge
from keras.models import Sequential, Model
from keras.layers import Dense, Input, Flatten, Add
from keras.layers import Activation, BatchNormalization, regularizers
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers.merge import concatenate
from keras.layers import LSTM, Bidirectional
from keras.utils import plot_model
from keras.layers import Dropout
from scipy import signal
import openpyxl

from keras.backend import tensorflow_backend as K
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
K.set_session(tf.Session(config=config))

class LossHistory(keras.callbacks.Callback):  # history = LossHistory()
    def init(self):  # history.init()
        self.losses = []
        # self.accs = []
        self.val_losses = []
        # self.val_accs = []
        self.mses = []
        self.maes = []
        self.mapes = []
        self.val_mses = []
        self.val_maes = []
        self.val_mapes = []

    def on_epoch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        # self.accs.append(logs.get('acc'))
        self.val_losses.append(logs.get('val_loss'))
        # self.val_accs.append(logs.get('val_accuracy
        self.mses.append(logs.get('mean_squared_error'))
        self.maes.append(logs.get('mean_absolute_error'))
        self.mapes.append(logs.get('mean_absolute_percentage_error'))
        self.val_mses.append(logs.get('val_mean_squared_error'))
        self.val_maes.append(logs.get('val_mean_absolute_error'))
        self.val_mapes.append(logs.get('val_mean_absolute_percentage_error'))

def create_dataset(dataset, timesteps):
    dataX, dataY = [], []
    for i in range(len(dataset) - timesteps - 1):
        a = dataset[i:(i + timesteps), 0]
        dataX.append(a)
        dataY.append(dataset[i + timesteps, 0])
    return np.array(dataX), np.array(dataY)

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

data_path = 'C:/Users/Smartgrid_ML/Desktop/KMS/climate_hour.csv'
data_source = pd.read_csv(data_path)
data_source = pd.DataFrame(data_source)
data_set = data_source.iloc[:, 2]
data = np.array(data_set)
data = data.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
Maxvalue_1 = scaler.data_max_
print(data.shape)

Tr_mean = np.nanmean(data)
Tr_var = np.nanvar(data)

print('Dataset mean = ', Tr_mean, 'var = ', Tr_var)
print('Maximum value = ', Maxvalue_1)

Training_set = data[0:42022, :]
Validation_set = data[42023:63031, :]
Test_set = data[63032:, :]

features = 1
timesteps = 24
trainX, trainY = create_dataset(Training_set, timesteps)
validX, validY = create_dataset(Validation_set, timesteps)
testX, testY = create_dataset(Test_set, timesteps)

trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
validX = np.reshape(validX, (validX.shape[0], validX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# -----------------------------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------------------------
visible1 = Input(shape=(timesteps, features))

bi11 = (Bidirectional(LSTM(16, return_sequences=True)))(visible1)  ### success
bi12 = (Bidirectional(LSTM(16, return_sequences=True)))(bi11)
res13 = keras.layers.Concatenate()([bi12, visible1])

bi13 = (Bidirectional(LSTM(16, return_sequences=True)))(res13)
bi14 = (Bidirectional(LSTM(16, return_sequences=True)))(bi13)
res14 = keras.layers.Concatenate()([bi14, res13, visible1])

bi15 = (Bidirectional(LSTM(16, return_sequences=True)))(res14)
bi16 = (Bidirectional(LSTM(16, return_sequences=True)))(bi15)
res15 = keras.layers.Concatenate()([bi16, res13, res14, visible1])

bi17 = (Bidirectional(LSTM(16, return_sequences=True)))(bi16)
bi18 = (Bidirectional(LSTM(16, return_sequences=True)))(bi17)
res16 = keras.layers.Concatenate()([bi18, res13, res14, res15, visible1])

bi19 = (Bidirectional(LSTM(16, return_sequences=True)))(res16)
bi20 = (Bidirectional(LSTM(16, return_sequences=True)))(bi19)
res17 = keras.layers.Concatenate()([bi20, res13, res14, res15, res16, visible1])

bi21 = (Bidirectional(LSTM(32)))(res17)

dense11 = Dense(24, activation='selu')(bi21)
out1 = Dense(1, activation='selu')(dense11)

model = Model(inputs=[visible1], outputs=[out1])  # multi-input, multi-output

#########################################

print(model.summary())

reducelr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=1)  # 에포크 1동안 좋아지지 않으면 호출

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse', 'mae', 'mape'])

batch_size = 100
epochs = 20

history = LossHistory()
history.init()

model.fit(trainX, trainY, epochs=epochs, batch_size=batch_size, shuffle=False, validation_data=(validX, validY), callbacks=[history, reducelr])  # , checkpoint

trainPredict = model.predict(trainX, batch_size=batch_size)
validPredict = model.predict(validX, batch_size=batch_size)
testPredict = model.predict(testX, batch_size=batch_size)

trainPredict = trainPredict.reshape([-1])
validPredict = validPredict.reshape([-1])
testPredict = testPredict.reshape([-1])
testY = testY.reshape([-1])
validY = validY.reshape([-1])
trainY = trainY.reshape([-1])

np.savetxt('trainPredict_5.txt', trainPredict)
np.savetxt('testPredict_5.txt', testPredict)
np.savetxt('validPredict_5.txt', validPredict)
np.savetxt('testY_5.txt', testY)
np.savetxt('validY_5.txt', validY)
np.savetxt('trainY_5.txt', trainY)

print('--------------------------------------------------------')
print(' history.mses(=loss) = ', history.mses)  # loss == mse
print(' history.maes        = ', history.maes)
print(' history.mapes        = ', history.mapes)
print(' history.val_mses(=loss)= ', history.val_mses)  # loss == mse
print(' history.val_maes       = ', history.val_maes)
print(' history.val_mapes       = ', history.val_mapes)
print('--------------------------------------------------------')

plt.figure(1)
plt.plot(testPredict, 'r')
plt.plot(testY, 'b')
plt.show()

plt.figure(2)
plt.plot(history.mses, 'b--')
plt.plot(history.val_mses, 'b:')
plt.plot(history.maes, 'ro')
plt.plot(history.val_maes, 'r+')
plt.ylabel('Loss and Accuracy')
plt.xlabel('epoch')
plt.show()

print('Test Score > MSE == ', mean_squared_error(testY, testPredict), ' MAE == ', mean_absolute_error(testY, testPredict), 'MAPE == ', mean_absolute_percentage_error(testY, testPredict))
# Out:
# (70037, 1)
# Dataset mean =  0.5363373411352942 var =  0.01966813341576947
# Maximum value =  [37.28]
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 24, 1)        0
# __________________________________________________________________________________________________
# bidirectional_12 (Bidirectional (None, 24, 32)       2304        input_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_13 (Bidirectional (None, 24, 32)       6272        bidirectional_12[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 24, 33)       0           bidirectional_13[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_14 (Bidirectional (None, 24, 32)       6400        concatenate_6[0][0]
# __________________________________________________________________________________________________
# bidirectional_15 (Bidirectional (None, 24, 32)       6272        bidirectional_14[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 24, 66)       0           bidirectional_15[0][0]
#                                                                  concatenate_6[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_16 (Bidirectional (None, 24, 32)       10624       concatenate_7[0][0]
# __________________________________________________________________________________________________
# bidirectional_17 (Bidirectional (None, 24, 32)       6272        bidirectional_16[0][0]
# __________________________________________________________________________________________________
# bidirectional_18 (Bidirectional (None, 24, 32)       6272        bidirectional_17[0][0]
# __________________________________________________________________________________________________
# bidirectional_19 (Bidirectional (None, 24, 32)       6272        bidirectional_18[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 24, 132)      0           bidirectional_17[0][0]
#                                                                  concatenate_6[0][0]
#                                                                  concatenate_7[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 24, 264)      0           bidirectional_19[0][0]
#                                                                  concatenate_6[0][0]
#                                                                  concatenate_7[0][0]
#                                                                  concatenate_8[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_20 (Bidirectional (None, 24, 32)       35968       concatenate_9[0][0]
# __________________________________________________________________________________________________
# bidirectional_21 (Bidirectional (None, 24, 32)       6272        bidirectional_20[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 24, 528)      0           bidirectional_21[0][0]
#                                                                  concatenate_6[0][0]
#                                                                  concatenate_7[0][0]
#                                                                  concatenate_8[0][0]
#                                                                  concatenate_9[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_22 (Bidirectional (None, 64)           143616      concatenate_10[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 24)           1560        bidirectional_22[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            25          dense_3[0][0]
# ==================================================================================================
# Total params: 238,129
# Trainable params: 238,129
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Train on 41997 samples, validate on 20983 samples
# Epoch 1/20
# 41997/41997 [==============================] - 243s 6ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - mean_absolute_error: 0.0333 - mean_absolute_percentage_error: 4645.5978 - val_loss: 5.1488e-04 - val_mean_squared_error: 5.1488e-04 - val_mean_absolute_error: 0.0170 - val_mean_absolute_percentage_error: 3.1741
# Epoch 2/20
# 41997/41997 [==============================] - 230s 5ms/step - loss: 4.2886e-04 - mean_squared_error: 4.2886e-04 - mean_absolute_error: 0.0158 - mean_absolute_percentage_error: 1081.6030 - val_loss: 6.2259e-04 - val_mean_squared_error: 6.2259e-04 - val_mean_absolute_error: 0.0192 - val_mean_absolute_percentage_error: 3.3628
# Epoch 3/20
# 41997/41997 [==============================] - 230s 5ms/step - loss: 2.7419e-04 - mean_squared_error: 2.7419e-04 - mean_absolute_error: 0.0122 - mean_absolute_percentage_error: 684.6121 - val_loss: 2.8009e-04 - val_mean_squared_error: 2.8009e-04 - val_mean_absolute_error: 0.0123 - val_mean_absolute_percentage_error: 2.3237
# Epoch 4/20
# 41997/41997 [==============================] - 229s 5ms/step - loss: 2.5285e-04 - mean_squared_error: 2.5285e-04 - mean_absolute_error: 0.0115 - mean_absolute_percentage_error: 450.5664 - val_loss: 2.4962e-04 - val_mean_squared_error: 2.4962e-04 - val_mean_absolute_error: 0.0115 - val_mean_absolute_percentage_error: 2.2034
# Epoch 5/20
# 41997/41997 [==============================] - 229s 5ms/step - loss: 2.4328e-04 - mean_squared_error: 2.4328e-04 - mean_absolute_error: 0.0112 - mean_absolute_percentage_error: 458.7400 - val_loss: 2.4516e-04 - val_mean_squared_error: 2.4516e-04 - val_mean_absolute_error: 0.0115 - val_mean_absolute_percentage_error: 2.2212
# Epoch 6/20
# 41997/41997 [==============================] - 230s 5ms/step - loss: 2.5082e-04 - mean_squared_error: 2.5082e-04 - mean_absolute_error: 0.0115 - mean_absolute_percentage_error: 475.7183 - val_loss: 2.4531e-04 - val_mean_squared_error: 2.4531e-04 - val_mean_absolute_error: 0.0115 - val_mean_absolute_percentage_error: 2.2520
# Epoch 7/20
# 41997/41997 [==============================] - 229s 5ms/step - loss: 2.4759e-04 - mean_squared_error: 2.4759e-04 - mean_absolute_error: 0.0115 - mean_absolute_percentage_error: 458.7577 - val_loss: 2.4233e-04 - val_mean_squared_error: 2.4233e-04 - val_mean_absolute_error: 0.0114 - val_mean_absolute_percentage_error: 2.2127
# Epoch 8/20
# 41997/41997 [==============================] - 230s 5ms/step - loss: 2.4640e-04 - mean_squared_error: 2.4640e-04 - mean_absolute_error: 0.0114 - mean_absolute_percentage_error: 450.7859 - val_loss: 2.4221e-04 - val_mean_squared_error: 2.4221e-04 - val_mean_absolute_error: 0.0114 - val_mean_absolute_percentage_error: 2.2107
# Epoch 9/20
# 41997/41997 [==============================] - 230s 5ms/step - loss: 2.4633e-04 - mean_squared_error: 2.4633e-04 - mean_absolute_error: 0.0114 - mean_absolute_percentage_error: 450.1500 - val_loss: 2.4221e-04 - val_mean_squared_error: 2.4221e-04 - val_mean_absolute_error: 0.0114 - val_mean_absolute_percentage_error: 2.2106
# Epoch 10/20
# 41997/41997 [==============================] - 228s 5ms/step - loss: 2.4632e-04 - mean_squared_error: 2.4632e-04 - mean_absolute_error: 0.0114 - mean_absolute_percentage_error: 450.1000 - val_loss: 2.4221e-04 - val_mean_squared_error: 2.4221e-04 - val_mean_absolute_error: 0.0114 - val_mean_absolute_percentage_error: 2.2106
# Epoch 11/20
# 41997/41997 [==============================] - 230s 5ms/step - loss: 2.4632e-04 - mean_squared_error: 2.4632e-04 - mean_absolute_error: 0.0114 - mean_absolute_percentage_error: 450.0954 - val_loss: 2.4221e-04 - val_mean_squared_error: 2.4221e-04 - val_mean_absolute_error: 0.0114 - val_mean_absolute_percentage_error: 2.2106
# Epoch 12/20
# 41997/41997 [==============================] - 229s 5ms/step - loss: 2.4632e-04 - mean_squared_error: 2.4632e-04 - mean_absolute_error: 0.0114 - mean_absolute_percentage_error: 450.0954 - val_loss: 2.4221e-04 - val_mean_squared_error: 2.4221e-04 - val_mean_absolute_error: 0.0114 - val_mean_absolute_percentage_error: 2.2106
# Epoch 13/20
# 41997/41997 [==============================] - 230s 5ms/step - loss: 2.4632e-04 - mean_squared_error: 2.4632e-04 - mean_absolute_error: 0.0114 - mean_absolute_percentage_error: 450.0954 - val_loss: 2.4221e-04 - val_mean_squared_error: 2.4221e-04 - val_mean_absolute_error: 0.0114 - val_mean_absolute_percentage_error: 2.2106
# Epoch 14/20
# 41997/41997 [==============================] - 230s 5ms/step - loss: 2.4632e-04 - mean_squared_error: 2.4632e-04 - mean_absolute_error: 0.0114 - mean_absolute_percentage_error: 450.0954 - val_loss: 2.4221e-04 - val_mean_squared_error: 2.4221e-04 - val_mean_absolute_error: 0.0114 - val_mean_absolute_percentage_error: 2.2106
# Epoch 15/20
# 41997/41997 [==============================] - 229s 5ms/step - loss: 2.4632e-04 - mean_squared_error: 2.4632e-04 - mean_absolute_error: 0.0114 - mean_absolute_percentage_error: 450.0954 - val_loss: 2.4221e-04 - val_mean_squared_error: 2.4221e-04 - val_mean_absolute_error: 0.0114 - val_mean_absolute_percentage_error: 2.2106
# Epoch 16/20
# 41997/41997 [==============================] - 228s 5ms/step - loss: 2.4632e-04 - mean_squared_error: 2.4632e-04 - mean_absolute_error: 0.0114 - mean_absolute_percentage_error: 450.0954 - val_loss: 2.4221e-04 - val_mean_squared_error: 2.4221e-04 - val_mean_absolute_error: 0.0114 - val_mean_absolute_percentage_error: 2.2106
# Epoch 17/20
# 41997/41997 [==============================] - 228s 5ms/step - loss: 2.4632e-04 - mean_squared_error: 2.4632e-04 - mean_absolute_error: 0.0114 - mean_absolute_percentage_error: 450.0954 - val_loss: 2.4221e-04 - val_mean_squared_error: 2.4221e-04 - val_mean_absolute_error: 0.0114 - val_mean_absolute_percentage_error: 2.2106
# Epoch 18/20
# 41997/41997 [==============================] - 229s 5ms/step - loss: 2.4632e-04 - mean_squared_error: 2.4632e-04 - mean_absolute_error: 0.0114 - mean_absolute_percentage_error: 450.0954 - val_loss: 2.4221e-04 - val_mean_squared_error: 2.4221e-04 - val_mean_absolute_error: 0.0114 - val_mean_absolute_percentage_error: 2.2106
# Epoch 19/20
# 41997/41997 [==============================] - 229s 5ms/step - loss: 2.4632e-04 - mean_squared_error: 2.4632e-04 - mean_absolute_error: 0.0114 - mean_absolute_percentage_error: 450.0954 - val_loss: 2.4221e-04 - val_mean_squared_error: 2.4221e-04 - val_mean_absolute_error: 0.0114 - val_mean_absolute_percentage_error: 2.2106
# Epoch 20/20
# 41997/41997 [==============================] - 228s 5ms/step - loss: 2.4632e-04 - mean_squared_error: 2.4632e-04 - mean_absolute_error: 0.0114 - mean_absolute_percentage_error: 450.0954 - val_loss: 2.4221e-04 - val_mean_squared_error: 2.4221e-04 - val_mean_absolute_error: 0.0114 - val_mean_absolute_percentage_error: 2.2106
# --------------------------------------------------------
#  history.mses(=loss) =  [0.002932232873352898, 0.0004288571716094581, 0.00027418974470712625, 0.00025284609150975435, 0.00024327821202350418, 0.00025082262939465715, 0.0002475908975470562, 0.00024640224546588536, 0.00024632638039835236, 0.0002463233589549524, 0.0002463231934244479, 0.00024632319044888844, 0.00024632319069143764, 0.00024632319069143764, 0.00024632319069143764, 0.00024632319069143764, 0.00024632319069143764, 0.00024632319069143764, 0.00024632319069143764, 0.00024632319069143764]
#  history.maes        =  [0.033322182322729925, 0.01580772280194894, 0.012157043551501781, 0.011518077517520101, 0.011208360800459932, 0.011546108124702144, 0.011475167732965133, 0.01141897030993024, 0.011415377533615075, 0.011415224177449964, 0.011415215441086712, 0.011415215586893457, 0.011415215604634201, 0.011415215604634201, 0.011415215604634201, 0.011415215604634201, 0.011415215604634201, 0.011415215604634201, 0.011415215604634201, 0.011415215604634201]
#  history.mapes        =  [4645.597836019022, 1081.6029878440697, 684.6121177839564, 450.5664120396566, 458.73995169334773, 475.7182789515645, 458.7576875502085, 450.7858693760191, 450.14995561958983, 450.1000167419193, 450.0954377640684, 450.0954377975629, 450.09543779614364, 450.09543779614364, 450.09543779614364, 450.09543779614364, 450.09543779614364, 450.09543779614364, 450.09543779614364, 450.09543779614364]
#  history.val_mses(=loss)=  [0.0005148836076298672, 0.0006225882789958737, 0.00028009498891386507, 0.0002496235750550451, 0.0002451554580048917, 0.00024531449388356637, 0.0002423349314087796, 0.00024221145095422407, 0.00024220625005408848, 0.0002422059802101356, 0.0002422059744196759, 0.00024220597493980822, 0.00024220597493980822, 0.00024220597493980822, 0.00024220597493980822, 0.00024220597493980822, 0.00024220597493980822, 0.00024220597493980822, 0.00024220597493980822, 0.00024220597493980822]
#  history.val_maes       =  [0.017045153814913838, 0.019188861671153613, 0.012274500713210746, 0.01150262081955749, 0.011454740220156473, 0.011517518231937189, 0.011377393905811432, 0.011370867341369786, 0.011370597669224233, 0.011370583021987474, 0.011370583313683227, 0.01137058333809477, 0.01137058333809477, 0.01137058333809477, 0.01137058333809477, 0.01137058333809477, 0.01137058333809477, 0.01137058333809477, 0.01137058333809477, 0.01137058333809477]
#  history.val_mapes       =  [3.1741460813714957, 3.3628376230170693, 2.3236505469063276, 2.2033779946545233, 2.221226822856679, 2.252049555628746, 2.2126607286778395, 2.210709368109402, 2.21063026354503, 2.210625950456012, 2.2106260021211352, 2.210626006666121, 2.210626006666121, 2.210626006666121, 2.210626006666121, 2.210626006666121, 2.210626006666121, 2.210626006666121, 2.210626006666121, 2.210626006666121]
# --------------------------------------------------------
# Test Score > MSE ==  0.000227634036624853  MAE ==  0.010977959787014156 MAPE ==  2.004125963281828
